# %% [markdown]
# ## Señales
#
# Las señales en PyQt5 son de suma importancia, estas permiten que puedas tener multiples Threads corriendo y puedan comunicarse entre si sin chocar. Se puede entender a las señales como mensajes que le comunican a un Thread que otro le está pidiendo que haga algo. El uso de señales permite que cada Thread tenga manejo sobre lo que está ocurriendo en su ejecución.
#
# ### ¿Como implemento señales en PyQt5?
#
# Muchos de los objetos de PyQt5 tienen sus propias señales. Por ejemplo, los `QPushButton` tiene una señal llamada `clicked` que se activa cuando se clickea el botón.
#
# ¿Como las señales pueden comunicarle a otro Thread que han sido activadas?
#
# Todas las señales tienen un método llamado `connect()`, que conecta la señal con la función que se entrega como párametro. De esta manera, para conectar la señal de clickeo de un QPushButton bastaría con escribir `my_button.clicked.connect(my_function)`.
#
# Siempre es bueno que usen las señales de los objetos con los que están trabajado. Por ejemplo, si tienen un QLineEdit, la señal `returnPressed` se activa cuando la tecla Enter es oprimida, por lo que puede ser muy útil conectarla a una función que procese el texto que escribieron en el QLineEdit.
#
# ### Usar señales personalizadas
#
# Puedes usar señales personalizadas cuando estes trabajando con cualquier QObject. Estas te permiten activarlas cuando lo necesites y enviar lo que quieras. Las señales son de la clase ´pyqtSignal´ que se encuentra en el módulo `PyQt5.Qt`.
#
# Cuando instancias una señal debes indicarle el tipo de objeto que esta enviará cuando sea activada. Para activar la señal se utiliza el método `emit`, que recibe un objeto del tipo que se le indicó al ser instanciada, y llama a la función a la cual está conectada entregandole el objeto que recibe `emit`. Esto se puede ver a continuación.

# %%
from PyQt5.QtWidgets import QMainWindow, QApplication
from PyQt5.QtCore import pyqtSignal
    
class MyWindow(QMainWindow):
    
    # Se le indica a la señal el tipo de objeto que enviará, en este caso un string.
    my_signal = pyqtSignal(str)
    
    def __init__(self):
        super().__init__()
        # Conectamos la señal a la función my_function.
        self.my_signal.connect(self.my_function)
        
        # Activamos la señal 2 veces
        self.my_signal.emit("Primera señal")
        self.my_signal.emit("Segunda señal")
    
    def my_function(self, string):
        print("Me han llamado")
        print(string)

if __name__ == '__main__':
    app = QApplication([])
    ex = MyWindow()
    ex.setGeometry(100,100,500,500)
    ex.show()
    app.exec_()
# Out:
# Me han llamado
# Primera señal
# Me han llamado
# Segunda señal

# %% [markdown]
# ### Importancia de las señales
#
# A continuación se encuentra un ejemplo que ilustra la importancia de las señales.
#
# Escribamos un programa en el que aparezcan circulos que se muevan cada cierto tiempo de 3 maneras distintas:
#
# 1-. Sin usar señales.
#
# 2-. Usando Señales.
#
# 3-. Usando Señales y eliminando `QThreads` con `DeleteLater`.
#
# ### Programa sin uso de señales

# %%
from PyQt5.QtWidgets import QLabel, QMainWindow, QApplication
from PyQt5.QtCore import QThread, QTimer
from PyQt5.QtGui import QPixmap
from time import sleep
from random import randint


class Food(QThread):

    def __init__(self, parent, x, y, max_width, max_height):
        """
        Un Food es un QThread que movera una imagen de comida
        en una ventana. El __init__ recibe los parametros:
            parent: ventana
            x e y: posicion inicial en la ventana
        """
        super().__init__()
        # Guardamos el path de la imagen que tendrá el Label
        self.food_image = "images/food/{}.png".format(randint(1, 9))
        # Creamos el Label y definimos su tamaño
        self.label = QLabel(parent)
        self.label.setGeometry(x, y, 50, 50)
        self.label.setPixmap(QPixmap(self.food_image))
        self.label.setScaledContents(True)
        self.label.show()
        self.label.setVisible(True)
        # Seteamos la posición inicial y la guardamos para usarla como una property
        self.__position = (0, 0)
        self.position = (x, y)
        #Guardamos los limites de la ventana para que no pueda salirse de ella
        self.max_width = max_width
        self.max_height = max_height
        self.start()

    @property
    def position(self):
        return self.__position

    @position.setter
    def position(self, value):
        self.__position = value
        self.label.move(self.position[0], self.position[1])

    def run(self):
        while True:
            sleep(0.1)
            new_x = self.position[0] + 1
            if new_x > self.max_width:
                new_x = randint(0, self.max_width)
            new_y = self.position[1] + 1
            if new_y > self.max_height:
                new_y = randint(0, self.max_height)
            self.position = (new_x, new_y)


class MyWindow(QMainWindow):
    def __init__(self):
        super().__init__()

        self.titulo = QLabel(self)
        self.titulo.setText("Ejemplo")
        self.titulo.move(160, 10)
        self.titulo.show()
        self.setGeometry(100, 100, 1200, 800)
        self.show()

        # Contador de cuanta comida hemos creado
        self.food_created = 0

        # Creamos un Timer que se encargara de crear la comida
        self.food_creator_timer = QTimer(self)
        self.food_creator_timer.timeout.connect(self.food_creator)
        self.food_creator_timer.start(50)

        self.foods = []

    def food_creator(self):
        new_food = Food(parent=self, x=randint(0, self.width()),
                        y=randint(0, self.height()), max_width=self.width(),
                        max_height=self.height())
        self.foods.append(new_food)
        self.food_created += 1
        print("Has creado {} unidades de comida\n".format(self.food_created))

if __name__ == '__main__':
    app = QApplication([])
    ex = MyWindow()
    app.exec_()
# Out:
# Has creado 1 unidades de comida
#
# Has creado 2 unidades de comida
#
# Has creado 3 unidades de comida
#
# Has creado 4 unidades de comida
#
# Has creado 5 unidades de comida
#
# Has creado 6 unidades de comida
#
# Has creado 7 unidades de comida
#
# Has creado 8 unidades de comida
#
# Has creado 9 unidades de comida
#
# Has creado 10 unidades de comida
#
# Has creado 11 unidades de comida
#
# Has creado 12 unidades de comida
#
# Has creado 13 unidades de comida
#
# Has creado 14 unidades de comida
#
# Has creado 15 unidades de comida
#
# Has creado 16 unidades de comida
#
# Has creado 17 unidades de comida
#
# Has creado 18 unidades de comida
#
# Has creado 19 unidades de comida
#
# Has creado 20 unidades de comida
#
# Has creado 21 unidades de comida
#
# Has creado 22 unidades de comida
#
# Has creado 23 unidades de comida
#
# Has creado 24 unidades de comida
#
# Has creado 25 unidades de comida
#
# Has creado 26 unidades de comida
#
# Has creado 27 unidades de comida
#
# Has creado 28 unidades de comida
#
# Has creado 29 unidades de comida
#
# Has creado 30 unidades de comida
#
# Has creado 31 unidades de comida
#
# Has creado 32 unidades de comida
#
# Has creado 33 unidades de comida
#
# Has creado 34 unidades de comida
#
# Has creado 35 unidades de comida
#
# Has creado 36 unidades de comida
#
# Has creado 37 unidades de comida
#
# Has creado 38 unidades de comida
#
# Has creado 39 unidades de comida
#
# Has creado 40 unidades de comida
#
# Has creado 41 unidades de comida
#
# Has creado 42 unidades de comida
#
# Has creado 43 unidades de comida
#
# Has creado 44 unidades de comida
#
# Has creado 45 unidades de comida
#
# Has creado 46 unidades de comida
#
# Has creado 47 unidades de comida
#
# Has creado 48 unidades de comida
#
# Has creado 49 unidades de comida
#
# Has creado 50 unidades de comida
#
# Has creado 51 unidades de comida
#
# Has creado 52 unidades de comida
#
# Has creado 53 unidades de comida
#
# Has creado 54 unidades de comida
#
# Has creado 55 unidades de comida
#
# Has creado 56 unidades de comida
#
# Has creado 57 unidades de comida
#
# Has creado 58 unidades de comida
#
# Has creado 59 unidades de comida
#
# Has creado 60 unidades de comida
#
# Has creado 61 unidades de comida
#
# Has creado 62 unidades de comida
#
# Has creado 63 unidades de comida
#
# Has creado 64 unidades de comida
#
# Has creado 65 unidades de comida
#
# Has creado 66 unidades de comida
#
# Has creado 67 unidades de comida
#
# Has creado 68 unidades de comida
#
# Has creado 69 unidades de comida
#
# Has creado 70 unidades de comida
#
# Has creado 71 unidades de comida
#
# Has creado 72 unidades de comida
#
# Has creado 73 unidades de comida
#
# Has creado 74 unidades de comida
#
# Has creado 75 unidades de comida
#
# Has creado 76 unidades de comida
#
# Has creado 77 unidades de comida
#
# Has creado 78 unidades de comida
#
# Has creado 79 unidades de comida
#
# Has creado 80 unidades de comida
#
# Has creado 81 unidades de comida
#
# Has creado 82 unidades de comida
#
# Has creado 83 unidades de comida
#
# Has creado 84 unidades de comida
#
# Has creado 85 unidades de comida
#
# Has creado 86 unidades de comida
#
# Has creado 87 unidades de comida
#
# Has creado 88 unidades de comida
#
# Has creado 89 unidades de comida
#
# Has creado 90 unidades de comida
#
# Has creado 91 unidades de comida
#
# Has creado 92 unidades de comida
#
# Has creado 93 unidades de comida
#
# Has creado 94 unidades de comida
#
# Has creado 95 unidades de comida
#
# Has creado 96 unidades de comida
#
# Has creado 97 unidades de comida
#
# Has creado 98 unidades de comida
#
# Has creado 99 unidades de comida
#
# Has creado 100 unidades de comida
#
# Has creado 101 unidades de comida
#
# Has creado 102 unidades de comida
#
# Has creado 103 unidades de comida
#
# Has creado 104 unidades de comida
#
# Has creado 105 unidades de comida
#
# Has creado 106 unidades de comida
#
# Has creado 107 unidades de comida
#
# Has creado 108 unidades de comida
#
# Has creado 109 unidades de comida
#
# Has creado 110 unidades de comida
#
# Has creado 111 unidades de comida
#
# Has creado 112 unidades de comida
#
# Has creado 113 unidades de comida
#
# Has creado 114 unidades de comida
#
# Has creado 115 unidades de comida
#
# Has creado 116 unidades de comida
#
# Has creado 117 unidades de comida
#
# Has creado 118 unidades de comida
#
# Has creado 119 unidades de comida
#
# Has creado 120 unidades de comida
#
# Has creado 121 unidades de comida
#
# Has creado 122 unidades de comida
#
# Has creado 123 unidades de comida
#
# Has creado 124 unidades de comida
#
# Has creado 125 unidades de comida
#
# Has creado 126 unidades de comida

# %% [markdown]
# Podemos observar que el programa se cae luego de crear cerca de 100 `QThreads`.
#
# ### Programa usando señales

# %%
from PyQt5.QtWidgets import QLabel, QMainWindow, QApplication
from PyQt5.QtCore import QThread, pyqtSignal, QTimer
from PyQt5.QtGui import QPixmap
from time import sleep
from random import randint

class MoveMyImageEvent:
    """
    Las instancias de esta clase
    contienen la informacion necesaria
    para que la ventana actualice
    la posicion de la imagen
    """

    def __init__(self, label, x, y):
        self.label = label
        self.x = x
        self.y = y


class Food(QThread):
    trigger = pyqtSignal(MoveMyImageEvent)
    # pyqtSignal recibe *args que le indican
    # cuales son los tipos de argumentos que seran enviados
    # en este caso, solo se enviara un argumento:
    # objeto clase MoveMyImageEvent, podria ser tambien int o str en caso
    # de que busquemos enviar este tipo de objetos en la señal.

    def __init__(self, parent, x, y, max_width, max_height):
        """
        Un Food es un QThread que movera una imagen de comida
        en una ventana. El __init__ recibe los parametros:
            parent: ventana
            x e y: posicion inicial en la ventana
        """
        super().__init__()
        # Guardamos el path de la imagen que tendrá el Label
        self.food_image = "images/food/{}.png".format(randint(1, 9))
        # Creamos el Label y definimos su tamaño
        self.label = QLabel(parent)
        self.label.setGeometry(x, y, 50, 50)
        self.label.setPixmap(QPixmap(self.food_image))
        self.label.setScaledContents(True)
        self.label.show()
        self.label.setVisible(True)
        # Seteamos la posición inicial y la guardamos para usarla como una property
        self.__position = (0, 0)
        self.position = (x, y)
        #Guardamos los limites de la ventana para que no pueda salirse de ella
        self.max_width = max_width
        self.max_height = max_height
        #self.trigger.connect(parent.actualizar_imagen)
        self.start()

    @property
    def position(self):
        return self.__position

    @position.setter
    def position(self, value):
        self.__position = value

        # El trigger emite su señal a la ventana cuando cambiamos la posición
        self.trigger.emit(MoveMyImageEvent(
            self.label, self.position[0], self.position[1]
        ))

    def run(self):
        while True:
            sleep(0.1)
            new_x = self.position[0] + 1
            if new_x > self.max_width:
                new_x = randint(0, self.max_width)
            new_y = self.position[1] + 1
            if new_y > self.max_height:
                new_y = randint(0, self.max_height)
            self.position = (new_x, new_y)


class MyWindow(QMainWindow):
    def __init__(self):
        super().__init__()

        self.titulo = QLabel(self)
        self.titulo.setText("Ejemplo")
        self.titulo.move(160, 10)
        self.titulo.show()
        self.setGeometry(100, 100, 1200, 800)
        self.show()

        # Contador de cuanta comida hemos creado
        self.food_created = 0

        # Creamos un Timer que se encargara de crear la comida
        self.food_creator_timer = QTimer(self)
        self.food_creator_timer.timeout.connect(self.food_creator)
        self.food_creator_timer.start(50)

        self.foods = []

    def food_creator(self):
        new_food = Food(parent=self, x=randint(0, self.width()),
                        y=randint(0, self.height()), max_width=self.width(),
                        max_height=self.height())
        new_food.trigger.connect(self.actualizar_imagen)
        self.foods.append(new_food)
        self.food_created += 1
        print("Has creado {} unidades de comida\n".format(self.food_created))

    @staticmethod
    def actualizar_imagen(myImageEvent):
        # Recibo el objeto con la información necesaria para mover a la comida
        label = myImageEvent.label
        label.move(myImageEvent.x, myImageEvent.y)

if __name__ == '__main__':
    app = QApplication([])
    ex = MyWindow()
    app.exec_()
# Out:
# Has creado 1 unidades de comida
#
# Has creado 2 unidades de comida
#
# Has creado 3 unidades de comida
#
# Has creado 4 unidades de comida
#
# Has creado 5 unidades de comida
#
# Has creado 6 unidades de comida
#
# Has creado 7 unidades de comida
#
# Has creado 8 unidades de comida
#
# Has creado 9 unidades de comida
#
# Has creado 10 unidades de comida
#
# Has creado 11 unidades de comida
#
# Has creado 12 unidades de comida
#
# Has creado 13 unidades de comida
#
# Has creado 14 unidades de comida
#
# Has creado 15 unidades de comida
#
# Has creado 16 unidades de comida
#
# Has creado 17 unidades de comida
#
# Has creado 18 unidades de comida
#
# Has creado 19 unidades de comida
#
# Has creado 20 unidades de comida
#
# Has creado 21 unidades de comida
#
# Has creado 22 unidades de comida
#
# Has creado 23 unidades de comida
#
# Has creado 24 unidades de comida
#
# Has creado 25 unidades de comida
#
# Has creado 26 unidades de comida
#
# Has creado 27 unidades de comida
#
# Has creado 28 unidades de comida
#
# Has creado 29 unidades de comida
#
# Has creado 30 unidades de comida
#
# Has creado 31 unidades de comida
#
# Has creado 32 unidades de comida
#
# Has creado 33 unidades de comida
#
# Has creado 34 unidades de comida
#
# Has creado 35 unidades de comida
#
# Has creado 36 unidades de comida
#
# Has creado 37 unidades de comida
#
# Has creado 38 unidades de comida
#
# Has creado 39 unidades de comida
#
# Has creado 40 unidades de comida
#
# Has creado 41 unidades de comida
#
# Has creado 42 unidades de comida
#
# Has creado 43 unidades de comida
#
# Has creado 44 unidades de comida
#
# Has creado 45 unidades de comida
#
# Has creado 46 unidades de comida
#
# Has creado 47 unidades de comida
#
# Has creado 48 unidades de comida
#
# Has creado 49 unidades de comida
#
# Has creado 50 unidades de comida
#
# Has creado 51 unidades de comida
#
# Has creado 52 unidades de comida
#
# Has creado 53 unidades de comida
#
# Has creado 54 unidades de comida
#
# Has creado 55 unidades de comida
#
# Has creado 56 unidades de comida
#
# Has creado 57 unidades de comida
#
# Has creado 58 unidades de comida
#
# Has creado 59 unidades de comida
#
# Has creado 60 unidades de comida
#
# Has creado 61 unidades de comida
#
# Has creado 62 unidades de comida
#
# Has creado 63 unidades de comida
#
# Has creado 64 unidades de comida
#
# Has creado 65 unidades de comida
#
# Has creado 66 unidades de comida
#
# Has creado 67 unidades de comida
#
# Has creado 68 unidades de comida
#
# Has creado 69 unidades de comida
#
# Has creado 70 unidades de comida
#
# Has creado 71 unidades de comida
#
# Has creado 72 unidades de comida
#
# Has creado 73 unidades de comida
#
# Has creado 74 unidades de comida
#
# Has creado 75 unidades de comida
#
# Has creado 76 unidades de comida
#
# Has creado 77 unidades de comida
#
# Has creado 78 unidades de comida
#
# Has creado 79 unidades de comida
#
# Has creado 80 unidades de comida
#
# Has creado 81 unidades de comida
#
# Has creado 82 unidades de comida
#
# Has creado 83 unidades de comida
#
# Has creado 84 unidades de comida
#
# Has creado 85 unidades de comida
#
# Has creado 86 unidades de comida
#
# Has creado 87 unidades de comida
#
# Has creado 88 unidades de comida
#
# Has creado 89 unidades de comida
#
# Has creado 90 unidades de comida
#
# Has creado 91 unidades de comida
#
# Has creado 92 unidades de comida
#
# Has creado 93 unidades de comida
#
# Has creado 94 unidades de comida
#
# Has creado 95 unidades de comida
#
# Has creado 96 unidades de comida
#
# Has creado 97 unidades de comida
#
# Has creado 98 unidades de comida
#
# Has creado 99 unidades de comida
#
# Has creado 100 unidades de comida
#
# Has creado 101 unidades de comida
#
# Has creado 102 unidades de comida
#
# Has creado 103 unidades de comida
#
# Has creado 104 unidades de comida
#
# Has creado 105 unidades de comida
#
# Has creado 106 unidades de comida
#
# Has creado 107 unidades de comida
#
# Has creado 108 unidades de comida
#
# Has creado 109 unidades de comida
#
# Has creado 110 unidades de comida
#
# Has creado 111 unidades de comida
#
# Has creado 112 unidades de comida
#
# Has creado 113 unidades de comida
#
# Has creado 114 unidades de comida
#
# Has creado 115 unidades de comida
#
# Has creado 116 unidades de comida
#
# Has creado 117 unidades de comida
#
# Has creado 118 unidades de comida
#
# Has creado 119 unidades de comida
#
# Has creado 120 unidades de comida
#
# Has creado 121 unidades de comida
#
# Has creado 122 unidades de comida
#
# Has creado 123 unidades de comida
#
# Has creado 124 unidades de comida
#
# Has creado 125 unidades de comida
#
# Has creado 126 unidades de comida
#
# Has creado 127 unidades de comida
#
# Has creado 128 unidades de comida
#
# Has creado 129 unidades de comida
#
# Has creado 130 unidades de comida
#
# Has creado 131 unidades de comida
#
# Has creado 132 unidades de comida
#
# Has creado 133 unidades de comida
#
# Has creado 134 unidades de comida
#
# Has creado 135 unidades de comida
#
# Has creado 136 unidades de comida
#
# Has creado 137 unidades de comida
#
# Has creado 138 unidades de comida
#
# Has creado 139 unidades de comida
#
# Has creado 140 unidades de comida
#
# Has creado 141 unidades de comida
#
# Has creado 142 unidades de comida
#
# Has creado 143 unidades de comida
#
# Has creado 144 unidades de comida
#
# Has creado 145 unidades de comida
#
# Has creado 146 unidades de comida
#
# Has creado 147 unidades de comida
#
# Has creado 148 unidades de comida
#
# Has creado 149 unidades de comida
#
# Has creado 150 unidades de comida
#
# Has creado 151 unidades de comida
#
# Has creado 152 unidades de comida
#
# Has creado 153 unidades de comida
#
# Has creado 154 unidades de comida
#
# Has creado 155 unidades de comida
#
# Has creado 156 unidades de comida
#
# Has creado 157 unidades de comida
#
# Has creado 158 unidades de comida
#
# Has creado 159 unidades de comida
#
# Has creado 160 unidades de comida
#
# Has creado 161 unidades de comida
#
# Has creado 162 unidades de comida
#
# Has creado 163 unidades de comida
#
# Has creado 164 unidades de comida
#
# Has creado 165 unidades de comida
#
# Has creado 166 unidades de comida
#
# Has creado 167 unidades de comida
#
# Has creado 168 unidades de comida
#
# Has creado 169 unidades de comida
#
# Has creado 170 unidades de comida
#
# Has creado 171 unidades de comida
#
# Has creado 172 unidades de comida
#
# Has creado 173 unidades de comida
#
# Has creado 174 unidades de comida
#
# Has creado 175 unidades de comida
#
# Has creado 176 unidades de comida
#
# Has creado 177 unidades de comida
#
# Has creado 178 unidades de comida
#
# Has creado 179 unidades de comida
#
# Has creado 180 unidades de comida
#
# Has creado 181 unidades de comida
#
# Has creado 182 unidades de comida
#
# Has creado 183 unidades de comida
#
# Has creado 184 unidades de comida
#
# Has creado 185 unidades de comida
#
# Has creado 186 unidades de comida
#
# Has creado 187 unidades de comida
#
# Has creado 188 unidades de comida
#
# Has creado 189 unidades de comida
#
# Has creado 190 unidades de comida
#
# Has creado 191 unidades de comida
#
# Has creado 192 unidades de comida
#
# Has creado 193 unidades de comida
#
# Has creado 194 unidades de comida
#
# Has creado 195 unidades de comida
#
# Has creado 196 unidades de comida
#
# Has creado 197 unidades de comida
#
# Has creado 198 unidades de comida
#
# Has creado 199 unidades de comida
#
# Has creado 200 unidades de comida
#
# Has creado 201 unidades de comida
#
# Has creado 202 unidades de comida
#
# Has creado 203 unidades de comida
#
# Has creado 204 unidades de comida
#
# Has creado 205 unidades de comida
#
# Has creado 206 unidades de comida
#
# Has creado 207 unidades de comida
#
# Has creado 208 unidades de comida
#
# Has creado 209 unidades de comida

# %% [markdown]
# Podemos observar que el programa se cae luego de crear cerca de 200 `QThreads`, lo cual es casi el doble que sin señales.
#
# ### Programa con señales y eliminando `QThreads` con `DeleteLater`.

# %%
from PyQt5.QtWidgets import QLabel, QMainWindow, QApplication
from PyQt5.QtCore import QThread, pyqtSignal, QTimer
from PyQt5.QtGui import QPixmap
from time import sleep
from random import randint


class MoveMyImageEvent:
    """
    Las instancias de esta clase
    contienen la informacion necesaria
    para que la ventana actualice
    la posicion de la imagen
    """
    def __init__(self, label, x, y):
        self.label = label
        self.x = x
        self.y = y


class Food(QThread):
    trigger = pyqtSignal(MoveMyImageEvent)

    # pyqtSignal recibe *args que le indican
    # cuales son los tipos de argumentos que seran enviados
    # en este caso, solo se enviara un argumento:
    #   objeto clase MoveMyImageEv

    def __init__(self, parent, x, y, max_width, max_height):
        """
        Un Food es un QThread que movera una imagen de comida
        en una ventana. El __init__ recibe los parametros:
            parent: ventana
            x e y: posicion inicial en la ventana
        """
        super().__init__()
        self.life = 100
        # Guardamos el path de la imagen que tendrá el Label
        self.food_image = "images/food/{}.png".format(randint(1, 9))
        # Creamos el Label y definimos su tamaño
        self.label = QLabel(parent)
        self.label.setGeometry(x, y, 50, 50)
        self.label.setPixmap(QPixmap(self.food_image))
        self.label.setScaledContents(True)
        self.label.show()
        self.label.setVisible(True)
        # Seteamos la posición inicial y la guardamos para usarla como una property
        self.__position = (0, 0)
        self.position = (x, y)
        # Guardamos los limites de la ventana para que no pueda salirse de ella
        self.max_width = max_width
        self.max_height = max_height
        self.start()

    @property
    def position(self):
        return self.__position

    @position.setter
    def position(self, value):
        self.__position = value

        # El trigger emite su señal a la ventana cuando cambiamos la posición
        self.trigger.emit(MoveMyImageEvent(
            self.label, self.position[0], self.position[1]
        ))


    def run(self):

        while self.life > 0:
            self.life -= 1
            sleep(0.1)
            new_x = self.position[0] + 1
            if new_x > self.max_width:
                new_x = randint(0, self.max_width)
            new_y = self.position[1] + 1
            if new_y > self.max_height:
                new_y = randint(0, self.max_height)
            self.position = (new_x, new_y)
        self.quit()
        self.label.deleteLater()


class MyWindow(QMainWindow):
    def __init__(self):
        super().__init__()

        self.titulo = QLabel(self)
        self.titulo.setText("Ejemplo")
        self.titulo.move(160, 10)
        self.titulo.show()
        self.setGeometry(100, 100, 1200, 800)
        self.show()

        # Contador de cuanta comida hemos creado
        self.food_created = 0

        # Creamos un Timer que se encargara de crear la comida
        self.food_creator_timer = QTimer(self)
        self.food_creator_timer.timeout.connect(self.food_creator)
        self.food_creator_timer.start(50)

        self.foods = []

    def food_creator(self):
        new_food = Food(parent=self, x=randint(0, self.width()),
                        y=randint(0, self.height()), max_width=self.width(),
                        max_height=self.height())
        new_food.trigger.connect(self.actualizar_imagen)
        self.foods.append(new_food)
        self.food_created += 1
        print("Has creado {} unidades de comida\n".format(self.food_created))

    @staticmethod
    def actualizar_imagen(myImageEvent):
        # Recibo el objeto con la información necesaria para mover a la comida
        label = myImageEvent.label
        label.move(myImageEvent.x, myImageEvent.y)


if __name__ == '__main__':
    app = QApplication([])
    ex = MyWindow()
    app.exec_()
# Out:
# Has creado 1 unidades de comida
#
# Has creado 2 unidades de comida
#
# Has creado 3 unidades de comida
#
# Has creado 4 unidades de comida
#
# Has creado 5 unidades de comida
#
# Has creado 6 unidades de comida
#
# Has creado 7 unidades de comida
#
# Has creado 8 unidades de comida
#
# Has creado 9 unidades de comida
#
# Has creado 10 unidades de comida
#
# Has creado 11 unidades de comida
#
# Has creado 12 unidades de comida
#
# Has creado 13 unidades de comida
#
# Has creado 14 unidades de comida
#
# Has creado 15 unidades de comida
#
# Has creado 16 unidades de comida
#
# Has creado 17 unidades de comida
#
# Has creado 18 unidades de comida
#
# Has creado 19 unidades de comida
#
# Has creado 20 unidades de comida
#
# Has creado 21 unidades de comida
#
# Has creado 22 unidades de comida
#
# Has creado 23 unidades de comida
#
# Has creado 24 unidades de comida
#
# Has creado 25 unidades de comida
#
# Has creado 26 unidades de comida
#
# Has creado 27 unidades de comida
#
# Has creado 28 unidades de comida
#
# Has creado 29 unidades de comida
#
# Has creado 30 unidades de comida
#
# Has creado 31 unidades de comida
#
# Has creado 32 unidades de comida
#
# Has creado 33 unidades de comida
#
# Has creado 34 unidades de comida
#
# Has creado 35 unidades de comida
#
# Has creado 36 unidades de comida
#
# Has creado 37 unidades de comida
#
# Has creado 38 unidades de comida
#
# Has creado 39 unidades de comida
#
# Has creado 40 unidades de comida
#
# Has creado 41 unidades de comida
#
# Has creado 42 unidades de comida
#
# Has creado 43 unidades de comida
#
# Has creado 44 unidades de comida
#
# Has creado 45 unidades de comida
#
# Has creado 46 unidades de comida
#
# Has creado 47 unidades de comida
#
# Has creado 48 unidades de comida
#
# Has creado 49 unidades de comida
#
# Has creado 50 unidades de comida
#
# Has creado 51 unidades de comida
#
# Has creado 52 unidades de comida
#
# Has creado 53 unidades de comida
#
# Has creado 54 unidades de comida
#
# Has creado 55 unidades de comida
#
# Has creado 56 unidades de comida
#
# Has creado 57 unidades de comida
#
# Has creado 58 unidades de comida
#
# Has creado 59 unidades de comida
#
# Has creado 60 unidades de comida
#
# Has creado 61 unidades de comida
#
# Has creado 62 unidades de comida
#
# Has creado 63 unidades de comida
#
# Has creado 64 unidades de comida
#
# Has creado 65 unidades de comida
#
# Has creado 66 unidades de comida
#
# Has creado 67 unidades de comida
#
# Has creado 68 unidades de comida
#
# Has creado 69 unidades de comida
#
# Has creado 70 unidades de comida
#
# Has creado 71 unidades de comida
#
# Has creado 72 unidades de comida
#
# Has creado 73 unidades de comida
#
# Has creado 74 unidades de comida
#
# Has creado 75 unidades de comida
#
# Has creado 76 unidades de comida
#
# Has creado 77 unidades de comida
#
# Has creado 78 unidades de comida
#
# Has creado 79 unidades de comida
#
# Has creado 80 unidades de comida
#
# Has creado 81 unidades de comida
#
# Has creado 82 unidades de comida
#
# Has creado 83 unidades de comida
#
# Has creado 84 unidades de comida
#
# Has creado 85 unidades de comida
#
# Has creado 86 unidades de comida
#
# Has creado 87 unidades de comida
#
# Has creado 88 unidades de comida
#
# Has creado 89 unidades de comida
#
# Has creado 90 unidades de comida
#
# Has creado 91 unidades de comida
#
# Has creado 92 unidades de comida
#
# Has creado 93 unidades de comida
#
# Has creado 94 unidades de comida
#
# Has creado 95 unidades de comida
#
# Has creado 96 unidades de comida
#
# Has creado 97 unidades de comida
#
# Has creado 98 unidades de comida
#
# Has creado 99 unidades de comida
#
# Has creado 100 unidades de comida
#
# Has creado 101 unidades de comida
#
# Has creado 102 unidades de comida
#
# Has creado 103 unidades de comida
#
# Has creado 104 unidades de comida
#
# Has creado 105 unidades de comida
#
# Has creado 106 unidades de comida
#
# Has creado 107 unidades de comida
#
# Has creado 108 unidades de comida
#
# Has creado 109 unidades de comida
#
# Has creado 110 unidades de comida
#
# Has creado 111 unidades de comida
#
# Has creado 112 unidades de comida
#
# Has creado 113 unidades de comida
#
# Has creado 114 unidades de comida
#
# Has creado 115 unidades de comida
#
# Has creado 116 unidades de comida
#
# Has creado 117 unidades de comida
#
# Has creado 118 unidades de comida
#
# Has creado 119 unidades de comida
#
# Has creado 120 unidades de comida
#
# Has creado 121 unidades de comida
#
# Has creado 122 unidades de comida
#
# Has creado 123 unidades de comida
#
# Has creado 124 unidades de comida
#
# Has creado 125 unidades de comida
#
# Has creado 126 unidades de comida
#
# Has creado 127 unidades de comida
#
# Has creado 128 unidades de comida
#
# Has creado 129 unidades de comida
#
# Has creado 130 unidades de comida
#
# Has creado 131 unidades de comida
#
# Has creado 132 unidades de comida
#
# Has creado 133 unidades de comida
#
# Has creado 134 unidades de comida
#
# Has creado 135 unidades de comida
#
# Has creado 136 unidades de comida
#
# Has creado 137 unidades de comida
#
# Has creado 138 unidades de comida
#
# Has creado 139 unidades de comida
#
# Has creado 140 unidades de comida
#
# Has creado 141 unidades de comida
#
# Has creado 142 unidades de comida
#
# Has creado 143 unidades de comida
#
# Has creado 144 unidades de comida
#
# Has creado 145 unidades de comida
#
# Has creado 146 unidades de comida
#
# Has creado 147 unidades de comida
#
# Has creado 148 unidades de comida
#
# Has creado 149 unidades de comida
#
# Has creado 150 unidades de comida
#
# Has creado 151 unidades de comida
#
# Has creado 152 unidades de comida
#
# Has creado 153 unidades de comida
#
# Has creado 154 unidades de comida
#
# Has creado 155 unidades de comida
#
# Has creado 156 unidades de comida
#
# Has creado 157 unidades de comida
#
# Has creado 158 unidades de comida
#
# Has creado 159 unidades de comida
#
# Has creado 160 unidades de comida
#
# Has creado 161 unidades de comida
#
# Has creado 162 unidades de comida
#
# Has creado 163 unidades de comida
#
# Has creado 164 unidades de comida
#
# Has creado 165 unidades de comida
#
# Has creado 166 unidades de comida
#
# Has creado 167 unidades de comida
#
# Has creado 168 unidades de comida
#
# Has creado 169 unidades de comida
#
# Has creado 170 unidades de comida
#
# Has creado 171 unidades de comida
#
# Has creado 172 unidades de comida
#
# Has creado 173 unidades de comida
#
# Has creado 174 unidades de comida
#
# Has creado 175 unidades de comida
#
# Has creado 176 unidades de comida
#
# Has creado 177 unidades de comida
#
# Has creado 178 unidades de comida
#
# Has creado 179 unidades de comida
#
# Has creado 180 unidades de comida
#
# Has creado 181 unidades de comida
#
# Has creado 182 unidades de comida
#
# Has creado 183 unidades de comida
#
# Has creado 184 unidades de comida
#
# Has creado 185 unidades de comida
#
# Has creado 186 unidades de comida
#
# Has creado 187 unidades de comida
#
# Has creado 188 unidades de comida
#
# Has creado 189 unidades de comida
#
# Has creado 190 unidades de comida
#
# Has creado 191 unidades de comida
#
# Has creado 192 unidades de comida
#
# Has creado 193 unidades de comida
#
# Has creado 194 unidades de comida
#
# Has creado 195 unidades de comida
#
# Has creado 196 unidades de comida
#
# Has creado 197 unidades de comida
#
# Has creado 198 unidades de comida
#
# Has creado 199 unidades de comida
#
# Has creado 200 unidades de comida
#
# Has creado 201 unidades de comida
#
# Has creado 202 unidades de comida
#
# Has creado 203 unidades de comida
#
# Has creado 204 unidades de comida
#
# Has creado 205 unidades de comida
#
# Has creado 206 unidades de comida
#
# Has creado 207 unidades de comida
#
# Has creado 208 unidades de comida
#
# Has creado 209 unidades de comida
#
# Has creado 210 unidades de comida
#
# Has creado 211 unidades de comida
#
# Has creado 212 unidades de comida
#
# Has creado 213 unidades de comida
#
# Has creado 214 unidades de comida
#
# Has creado 215 unidades de comida
#
# Has creado 216 unidades de comida
#
# Has creado 217 unidades de comida
#
# Has creado 218 unidades de comida
#
# Has creado 219 unidades de comida
#
# Has creado 220 unidades de comida
#
# Has creado 221 unidades de comida
#
# Has creado 222 unidades de comida
#
# Has creado 223 unidades de comida
#
# Has creado 224 unidades de comida
#
# Has creado 225 unidades de comida
#
# Has creado 226 unidades de comida
#
# Has creado 227 unidades de comida
#
# Has creado 228 unidades de comida
#
# Has creado 229 unidades de comida
#
# Has creado 230 unidades de comida
#
# Has creado 231 unidades de comida
#
# Has creado 232 unidades de comida
#
# Has creado 233 unidades de comida
#
# Has creado 234 unidades de comida
#
# Has creado 235 unidades de comida
#
# Has creado 236 unidades de comida
#
# Has creado 237 unidades de comida
#
# Has creado 238 unidades de comida
# Has creado 239 unidades de comida
#
# Has creado 240 unidades de comida
#
# Has creado 241 unidades de comida
#
# Has creado 242 unidades de comida
#
# Has creado 243 unidades de comida
#
# Has creado 244 unidades de comida
#
# Has creado 245 unidades de comida
#
# Has creado 246 unidades de comida
#
# Has creado 247 unidades de comida
#
# Has creado 248 unidades de comida
#
# Has creado 249 unidades de comida
#
# Has creado 250 unidades de comida
#
# Has creado 251 unidades de comida
#
# Has creado 252 unidades de comida
#
# Has creado 253 unidades de comida
#
# Has creado 254 unidades de comida
#
# Has creado 255 unidades de comida
#
# Has creado 256 unidades de comida
#
# Has creado 257 unidades de comida
#
# Has creado 258 unidades de comida
#
# Has creado 259 unidades de comida
#
# Has creado 260 unidades de comida
#
# Has creado 261 unidades de comida
#
# Has creado 262 unidades de comida
#
# Has creado 263 unidades de comida
#
# Has creado 264 unidades de comida
#
# Has creado 265 unidades de comida
#
# Has creado 266 unidades de comida
#
# Has creado 267 unidades de comida
#
# Has creado 268 unidades de comida
#
# Has creado 269 unidades de comida
#
# Has creado 270 unidades de comida
#
# Has creado 271 unidades de comida
#
# Has creado 272 unidades de comida
#
# Has creado 273 unidades de comida
#
# Has creado 274 unidades de comida
#
# Has creado 275 unidades de comida
#
# Has creado 276 unidades de comida
#
# Has creado 277 unidades de comida
#
# Has creado 278 unidades de comida
#
# Has creado 279 unidades de comida
#
# Has creado 280 unidades de comida
#
# Has creado 281 unidades de comida
#
# Has creado 282 unidades de comida
#
# Has creado 283 unidades de comida
#
# Has creado 284 unidades de comida
#
# Has creado 285 unidades de comida
#
# Has creado 286 unidades de comida
#
# Has creado 287 unidades de comida
#
# Has creado 288 unidades de comida
#
# Has creado 289 unidades de comida
#
# Has creado 290 unidades de comida
#
# Has creado 291 unidades de comida
#
# Has creado 292 unidades de comida
#
# Has creado 293 unidades de comida
#
# Has creado 294 unidades de comida
#
# Has creado 295 unidades de comida
#
# Has creado 296 unidades de comida
#
# Has creado 297 unidades de comida
#
# Has creado 298 unidades de comida
#
# Has creado 299 unidades de comida
#
# Has creado 300 unidades de comida
#
# Has creado 301 unidades de comida
#
# Has creado 302 unidades de comida
#
# Has creado 303 unidades de comida
#
# Has creado 304 unidades de comida
#
# Has creado 305 unidades de comida
#
# Has creado 306 unidades de comida
#
# Has creado 307 unidades de comida
#
# Has creado 308 unidades de comida
#
# Has creado 309 unidades de comida
#
# Has creado 310 unidades de comida
#
# Has creado 311 unidades de comida
#
# Has creado 312 unidades de comida
#
# Has creado 313 unidades de comida
#
# Has creado 314 unidades de comida
#
# Has creado 315 unidades de comida
#
# Has creado 316 unidades de comida
#
# Has creado 317 unidades de comida
#
# Has creado 318 unidades de comida
#
# Has creado 319 unidades de comida
#
# Has creado 320 unidades de comida
#
# Has creado 321 unidades de comida
#
# Has creado 322 unidades de comida
#
# Has creado 323 unidades de comida
#
# Has creado 324 unidades de comida
#
# Has creado 325 unidades de comida
#
# Has creado 326 unidades de comida
#
# Has creado 327 unidades de comida
#
# Has creado 328 unidades de comida
#
# Has creado 329 unidades de comida
#
# Has creado 330 unidades de comida
#
# Has creado 331 unidades de comida
#
# Has creado 332 unidades de comida
#
# Has creado 333 unidades de comida
#
# Has creado 334 unidades de comida
#
# Has creado 335 unidades de comida
#
# Has creado 336 unidades de comida
#
# Has creado 337 unidades de comida
#
# Has creado 338 unidades de comida
#
# Has creado 339 unidades de comida
#
# Has creado 340 unidades de comida
#
# Has creado 341 unidades de comida
#
# Has creado 342 unidades de comida
#
# Has creado 343 unidades de comida
#
# Has creado 344 unidades de comida
#
# Has creado 345 unidades de comida
#
# Has creado 346 unidades de comida
#
# Has creado 347 unidades de comida
#
# Has creado 348 unidades de comida
#
# Has creado 349 unidades de comida
#
# Has creado 350 unidades de comida
#
# Has creado 351 unidades de comida
#
# Has creado 352 unidades de comida
#
# Has creado 353 unidades de comida
#
# Has creado 354 unidades de comida
#
# Has creado 355 unidades de comida
#
# Has creado 356 unidades de comida
#
# Has creado 357 unidades de comida
#
# Has creado 358 unidades de comida
#
# Has creado 359 unidades de comida
#
# Has creado 360 unidades de comida
#
# Has creado 361 unidades de comida
#
# Has creado 362 unidades de comida
#
# Has creado 363 unidades de comida
#
# Has creado 364 unidades de comida
#
# Has creado 365 unidades de comida
#
# Has creado 366 unidades de comida
#
# Has creado 367 unidades de comida
#
# Has creado 368 unidades de comida
#
# Has creado 369 unidades de comida
#
# Has creado 370 unidades de comida
#
# Has creado 371 unidades de comida
#
# Has creado 372 unidades de comida
#
# Has creado 373 unidades de comida
#
# Has creado 374 unidades de comida
#
# Has creado 375 unidades de comida
#
# Has creado 376 unidades de comida
#
# Has creado 377 unidades de comida
#
# Has creado 378 unidades de comida
#
# Has creado 379 unidades de comida
#
# Has creado 380 unidades de comida
#
# Has creado 381 unidades de comida
#
# Has creado 382 unidades de comida
#
# Has creado 383 unidades de comida
#
# Has creado 384 unidades de comida
#
# Has creado 385 unidades de comida
#
# Has creado 386 unidades de comida
#
# Has creado 387 unidades de comida
#
# Has creado 388 unidades de comida
#
# Has creado 389 unidades de comida
#
# Has creado 390 unidades de comida
#
# Has creado 391 unidades de comida
#
# Has creado 392 unidades de comida
#
# Has creado 393 unidades de comida
#
# Has creado 394 unidades de comida
#
# Has creado 395 unidades de comida
#
# Has creado 396 unidades de comida
#
# Has creado 397 unidades de comida
#
# Has creado 398 unidades de comida
#
# Has creado 399 unidades de comida
#
# Has creado 400 unidades de comida
#
# Has creado 401 unidades de comida
#
# Has creado 402 unidades de comida
#
# Has creado 403 unidades de comida
#
# Has creado 404 unidades de comida
#
# Has creado 405 unidades de comida
#
# Has creado 406 unidades de comida
#
# Has creado 407 unidades de comida
#
# Has creado 408 unidades de comida
#
# Has creado 409 unidades de comida
#
# Has creado 410 unidades de comida
#
# Has creado 411 unidades de comida
#
# Has creado 412 unidades de comida
#
# Has creado 413 unidades de comida
#
# Has creado 414 unidades de comida
#
# Has creado 415 unidades de comida
#
# Has creado 416 unidades de comida
#
# Has creado 417 unidades de comida
#
# Has creado 418 unidades de comida
#
# Has creado 419 unidades de comida
#
# Has creado 420 unidades de comida
#
# Has creado 421 unidades de comida
#
# Has creado 422 unidades de comida
#
# Has creado 423 unidades de comida
#
# Has creado 424 unidades de comida
#
# Has creado 425 unidades de comida
#
# Has creado 426 unidades de comida
#
# Has creado 427 unidades de comida
#
# Has creado 428 unidades de comida
#
# Has creado 429 unidades de comida
#
# Has creado 430 unidades de comida
#
# Has creado 431 unidades de comida
#
# Has creado 432 unidades de comida
#
# Has creado 433 unidades de comida
#
# Has creado 434 unidades de comida
#
# Has creado 435 unidades de comida
#
# Has creado 436 unidades de comida
#
# Has creado 437 unidades de comida
#
# Has creado 438 unidades de comida
#
# Has creado 439 unidades de comida
#
# Has creado 440 unidades de comida
#
# Has creado 441 unidades de comida
#
# Has creado 442 unidades de comida
#
# Has creado 443 unidades de comida
#
# Has creado 444 unidades de comida
#
# Has creado 445 unidades de comida
#
# Has creado 446 unidades de comida
#
# Has creado 447 unidades de comida
#
# Has creado 448 unidades de comida
#
# Has creado 449 unidades de comida
#
# Has creado 450 unidades de comida
#
# Has creado 451 unidades de comida
#
# Has creado 452 unidades de comida
#
# Has creado 453 unidades de comida
#
# Has creado 454 unidades de comida
#
# Has creado 455 unidades de comida
#
# Has creado 456 unidades de comida
#
# Has creado 457 unidades de comida
#
# Has creado 458 unidades de comida
#
# Has creado 459 unidades de comida
#
# Has creado 460 unidades de comida
#
# Has creado 461 unidades de comida
#
# Has creado 462 unidades de comida
#
# Has creado 463 unidades de comida
#
# Has creado 464 unidades de comida
#
# Has creado 465 unidades de comida
#
# Has creado 466 unidades de comida
#
# Has creado 467 unidades de comida
#
# Has creado 468 unidades de comida
#
# Has creado 469 unidades de comida
#
# Has creado 470 unidades de comida
#
# Has creado 471 unidades de comida
#
# Has creado 472 unidades de comida
#
# Has creado 473 unidades de comida
# Has creado 474 unidades de comida
#
# Has creado 475 unidades de comida
#
# Has creado 476 unidades de comida
#
# Has creado 477 unidades de comida
#
# Has creado 478 unidades de comida
#
# Has creado 479 unidades de comida
#
# Has creado 480 unidades de comida
#
# Has creado 481 unidades de comida
#
# Has creado 482 unidades de comida
#
# Has creado 483 unidades de comida
#
# Has creado 484 unidades de comida
#
# Has creado 485 unidades de comida
#
# Has creado 486 unidades de comida
#
# Has creado 487 unidades de comida
#
# Has creado 488 unidades de comida
#
# Has creado 489 unidades de comida
#
# Has creado 490 unidades de comida
#
# Has creado 491 unidades de comida
#
# Has creado 492 unidades de comida
#
# Has creado 493 unidades de comida
#
# Has creado 494 unidades de comida
#
# Has creado 495 unidades de comida
#
# Has creado 496 unidades de comida
#
# Has creado 497 unidades de comida
#
# Has creado 498 unidades de comida
#
# Has creado 499 unidades de comida
#
# Has creado 500 unidades de comida
#
# Has creado 501 unidades de comida
#
# Has creado 502 unidades de comida
#
# Has creado 503 unidades de comida
#
# Has creado 504 unidades de comida
#
# Has creado 505 unidades de comida
#
# Has creado 506 unidades de comida
#
# Has creado 507 unidades de comida
#
# Has creado 508 unidades de comida
#
# Has creado 509 unidades de comida
#
# Has creado 510 unidades de comida
#
# Has creado 511 unidades de comida
#
# Has creado 512 unidades de comida
#
# Has creado 513 unidades de comida
#
# Has creado 514 unidades de comida
#
# Has creado 515 unidades de comida
#
# Has creado 516 unidades de comida
#
# Has creado 517 unidades de comida
#
# Has creado 518 unidades de comida
#
# Has creado 519 unidades de comida
#
# Has creado 520 unidades de comida
#
# Has creado 521 unidades de comida
#
# Has creado 522 unidades de comida
#
# Has creado 523 unidades de comida
#
# Has creado 524 unidades de comida
#
# Has creado 525 unidades de comida
#
# Has creado 526 unidades de comida
#
# Has creado 527 unidades de comida
#
# Has creado 528 unidades de comida
#
# Has creado 529 unidades de comida
#
# Has creado 530 unidades de comida
#
# Has creado 531 unidades de comida
#
# Has creado 532 unidades de comida
#
# Has creado 533 unidades de comida
#
# Has creado 534 unidades de comida
#
# Has creado 535 unidades de comida
#
# Has creado 536 unidades de comida
#
# Has creado 537 unidades de comida
#
# Has creado 538 unidades de comida
#
# Has creado 539 unidades de comida
#
# Has creado 540 unidades de comida
#
# Has creado 541 unidades de comida
#
# Has creado 542 unidades de comida
#
# Has creado 543 unidades de comida
#
# Has creado 544 unidades de comida
#
# Has creado 545 unidades de comida
#
# Has creado 546 unidades de comida
#
# Has creado 547 unidades de comida
#
# Has creado 548 unidades de comida
#
# Has creado 549 unidades de comida
#
# Has creado 550 unidades de comida
#
# Has creado 551 unidades de comida
#
# Has creado 552 unidades de comida
#
# Has creado 553 unidades de comida
#
# Has creado 554 unidades de comida
#
# Has creado 555 unidades de comida
#
# Has creado 556 unidades de comida
#
# Has creado 557 unidades de comida
#
# Has creado 558 unidades de comida
#
# Has creado 559 unidades de comida
#
# Has creado 560 unidades de comida
#
# Has creado 561 unidades de comida
#
# Has creado 562 unidades de comida
#
# Has creado 563 unidades de comida
#
# Has creado 564 unidades de comida
#
# Has creado 565 unidades de comida
#
# Has creado 566 unidades de comida
#
# Has creado 567 unidades de comida
#
# Has creado 568 unidades de comida
#
# Has creado 569 unidades de comida
#
# Has creado 570 unidades de comida
#
# Has creado 571 unidades de comida
#
# Has creado 572 unidades de comida
#
# Has creado 573 unidades de comida
#
# Has creado 574 unidades de comida
#
# Has creado 575 unidades de comida
#
# Has creado 576 unidades de comida
#
# Has creado 577 unidades de comida
#
# Has creado 578 unidades de comida
#
# Has creado 579 unidades de comida
#
# Has creado 580 unidades de comida
#
# Has creado 581 unidades de comida
#
# Has creado 582 unidades de comida
#
# Has creado 583 unidades de comida
#
# Has creado 584 unidades de comida
#
# Has creado 585 unidades de comida
#
# Has creado 586 unidades de comida
#
# Has creado 587 unidades de comida
#
# Has creado 588 unidades de comida
#
# Has creado 589 unidades de comida
#
# Has creado 590 unidades de comida
#
# Has creado 591 unidades de comida
#
# Has creado 592 unidades de comida
#
# Has creado 593 unidades de comida
#
# Has creado 594 unidades de comida
#
# Has creado 595 unidades de comida
#
# Has creado 596 unidades de comida
#
# Has creado 597 unidades de comida
#
# Has creado 598 unidades de comida
#
# Has creado 599 unidades de comida
#
# Has creado 600 unidades de comida
#
# Has creado 601 unidades de comida
#
# Has creado 602 unidades de comida
#
# Has creado 603 unidades de comida
#
# Has creado 604 unidades de comida
#
# Has creado 605 unidades de comida
#
# Has creado 606 unidades de comida
#
# Has creado 607 unidades de comida
#
# Has creado 608 unidades de comida
#
# Has creado 609 unidades de comida
#
# Has creado 610 unidades de comida
#
# Has creado 611 unidades de comida
#
# Has creado 612 unidades de comida
#
# Has creado 613 unidades de comida
#
# Has creado 614 unidades de comida
#
# Has creado 615 unidades de comida
#
# Has creado 616 unidades de comida
#
# Has creado 617 unidades de comida
#
# Has creado 618 unidades de comida
#
# Has creado 619 unidades de comida
#
# Has creado 620 unidades de comida
#
# Has creado 621 unidades de comida
#
# Has creado 622 unidades de comida
#
# Has creado 623 unidades de comida
#
# Has creado 624 unidades de comida
#
# Has creado 625 unidades de comida
#
# Has creado 626 unidades de comida
#
# Has creado 627 unidades de comida
#
# Has creado 628 unidades de comida
#
# Has creado 629 unidades de comida
#
# Has creado 630 unidades de comida
#
# Has creado 631 unidades de comida
#
# Has creado 632 unidades de comida
#
# Has creado 633 unidades de comida
#
# Has creado 634 unidades de comida
#
# Has creado 635 unidades de comida
#
# Has creado 636 unidades de comida
#
# Has creado 637 unidades de comida
#
# Has creado 638 unidades de comida
#
# Has creado 639 unidades de comida
#
# Has creado 640 unidades de comida
#
# Has creado 641 unidades de comida
#
# Has creado 642 unidades de comida
#
# Has creado 643 unidades de comida
#
# Has creado 644 unidades de comida
#
# Has creado 645 unidades de comida
#
# Has creado 646 unidades de comida
#
# Has creado 647 unidades de comida
#
# Has creado 648 unidades de comida
#
# Has creado 649 unidades de comida
#
# Has creado 650 unidades de comida
#
# Has creado 651 unidades de comida
#
# Has creado 652 unidades de comida
#
# Has creado 653 unidades de comida
#
# Has creado 654 unidades de comida
#
# Has creado 655 unidades de comida
#
# Has creado 656 unidades de comida
#
# Has creado 657 unidades de comida
#
# Has creado 658 unidades de comida
#
# Has creado 659 unidades de comida
#
# Has creado 660 unidades de comida
#
# Has creado 661 unidades de comida
#
# Has creado 662 unidades de comida
#
# Has creado 663 unidades de comida
#
# Has creado 664 unidades de comida
#
# Has creado 665 unidades de comida
#
# Has creado 666 unidades de comida
#
# Has creado 667 unidades de comida
#
# Has creado 668 unidades de comida
#
# Has creado 669 unidades de comida
#
# Has creado 670 unidades de comida
#
# Has creado 671 unidades de comida
#
# Has creado 672 unidades de comida
#
# Has creado 673 unidades de comida
#
# Has creado 674 unidades de comida
#
# Has creado 675 unidades de comida
#
# Has creado 676 unidades de comida
#
# Has creado 677 unidades de comida
#
# Has creado 678 unidades de comida
#
# Has creado 679 unidades de comida
#
# Has creado 680 unidades de comida
#
# Has creado 681 unidades de comida
#
# Has creado 682 unidades de comida
#
# Has creado 683 unidades de comida
#
# Has creado 684 unidades de comida
#
# Has creado 685 unidades de comida
#
# Has creado 686 unidades de comida
#
# Has creado 687 unidades de comida
#
# Has creado 688 unidades de comida
#
# Has creado 689 unidades de comida
#
# Has creado 690 unidades de comida
#
# Has creado 691 unidades de comida
#
# Has creado 692 unidades de comida
#
# Has creado 693 unidades de comida
#
# Has creado 694 unidades de comida
#
# Has creado 695 unidades de comida
#
# Has creado 696 unidades de comida
#
# Has creado 697 unidades de comida
#
# Has creado 698 unidades de comida
#
# Has creado 699 unidades de comida
#
# Has creado 700 unidades de comida
#
# Has creado 701 unidades de comida
#
# Has creado 702 unidades de comida
#
# Has creado 703 unidades de comida
#
# Has creado 704 unidades de comida
#
# Has creado 705 unidades de comida
#
# Has creado 706 unidades de comida
#
# Has creado 707 unidades de comida
#
# Has creado 708 unidades de comida
#
# Has creado 709 unidades de comida
# Has creado 710 unidades de comida
#
# Has creado 711 unidades de comida
#
# Has creado 712 unidades de comida
#
# Has creado 713 unidades de comida
#
# Has creado 714 unidades de comida
#
# Has creado 715 unidades de comida
#
# Has creado 716 unidades de comida
#
# Has creado 717 unidades de comida
#
# Has creado 718 unidades de comida
#
# Has creado 719 unidades de comida
#
# Has creado 720 unidades de comida
#
# Has creado 721 unidades de comida
#
# Has creado 722 unidades de comida
#
# Has creado 723 unidades de comida
#
# Has creado 724 unidades de comida
#
# Has creado 725 unidades de comida
#
# Has creado 726 unidades de comida
#
# Has creado 727 unidades de comida
#
# Has creado 728 unidades de comida
#
# Has creado 729 unidades de comida
#
# Has creado 730 unidades de comida
#
# Has creado 731 unidades de comida
#
# Has creado 732 unidades de comida
#
# Has creado 733 unidades de comida
#
# Has creado 734 unidades de comida
#
# Has creado 735 unidades de comida
#
# Has creado 736 unidades de comida
#
# Has creado 737 unidades de comida
#
# Has creado 738 unidades de comida
#
# Has creado 739 unidades de comida
#
# Has creado 740 unidades de comida
#
# Has creado 741 unidades de comida
#
# Has creado 742 unidades de comida
#
# Has creado 743 unidades de comida
#
# Has creado 744 unidades de comida
#
# Has creado 745 unidades de comida
#
# Has creado 746 unidades de comida
#
# Has creado 747 unidades de comida
#
# Has creado 748 unidades de comida
#
# Has creado 749 unidades de comida
#
# Has creado 750 unidades de comida
#
# Has creado 751 unidades de comida
#
# Has creado 752 unidades de comida
#
# Has creado 753 unidades de comida
#
# Has creado 754 unidades de comida
#
# Has creado 755 unidades de comida
#
# Has creado 756 unidades de comida
#
# Has creado 757 unidades de comida
#
# Has creado 758 unidades de comida
#
# Has creado 759 unidades de comida
#
# Has creado 760 unidades de comida
#
# Has creado 761 unidades de comida
#
# Has creado 762 unidades de comida
#
# Has creado 763 unidades de comida
#
# Has creado 764 unidades de comida
#
# Has creado 765 unidades de comida
#
# Has creado 766 unidades de comida
#
# Has creado 767 unidades de comida
#
# Has creado 768 unidades de comida
#
# Has creado 769 unidades de comida
#
# Has creado 770 unidades de comida
#
# Has creado 771 unidades de comida
#
# Has creado 772 unidades de comida
#
# Has creado 773 unidades de comida
#
# Has creado 774 unidades de comida
#
# Has creado 775 unidades de comida
#
# Has creado 776 unidades de comida
#
# Has creado 777 unidades de comida
#
# Has creado 778 unidades de comida
#
# Has creado 779 unidades de comida
#
# Has creado 780 unidades de comida
#
# Has creado 781 unidades de comida
#
# Has creado 782 unidades de comida
#
# Has creado 783 unidades de comida
#
# Has creado 784 unidades de comida
#
# Has creado 785 unidades de comida
#
# Has creado 786 unidades de comida
#
# Has creado 787 unidades de comida
#
# Has creado 788 unidades de comida
#
# Has creado 789 unidades de comida
#
# Has creado 790 unidades de comida
#
# Has creado 791 unidades de comida
#
# Has creado 792 unidades de comida
#
# Has creado 793 unidades de comida
#
# Has creado 794 unidades de comida
#
# Has creado 795 unidades de comida
#
# Has creado 796 unidades de comida
#
# Has creado 797 unidades de comida
#
# Has creado 798 unidades de comida
#
# Has creado 799 unidades de comida
#
# Has creado 800 unidades de comida
#
# Has creado 801 unidades de comida
#
# Has creado 802 unidades de comida
#
# Has creado 803 unidades de comida
#
# Has creado 804 unidades de comida
#
# Has creado 805 unidades de comida
#
# Has creado 806 unidades de comida
#
# Has creado 807 unidades de comida
#
# Has creado 808 unidades de comida
#
# Has creado 809 unidades de comida
#
# Has creado 810 unidades de comida
#
# Has creado 811 unidades de comida
#
# Has creado 812 unidades de comida
#
# Has creado 813 unidades de comida
#
# Has creado 814 unidades de comida
#
# Has creado 815 unidades de comida
#
# Has creado 816 unidades de comida
#
# Has creado 817 unidades de comida
#
# Has creado 818 unidades de comida
#
# Has creado 819 unidades de comida
#
# Has creado 820 unidades de comida
#
# Has creado 821 unidades de comida
#
# Has creado 822 unidades de comida
#
# Has creado 823 unidades de comida
#
# Has creado 824 unidades de comida
#
# Has creado 825 unidades de comida
#
# Has creado 826 unidades de comida
#
# Has creado 827 unidades de comida
#
# Has creado 828 unidades de comida
#
# Has creado 829 unidades de comida
#
# Has creado 830 unidades de comida
#
# Has creado 831 unidades de comida
#
# Has creado 832 unidades de comida
#
# Has creado 833 unidades de comida
#
# Has creado 834 unidades de comida
#
# Has creado 835 unidades de comida
#
# Has creado 836 unidades de comida
#
# Has creado 837 unidades de comida
#
# Has creado 838 unidades de comida
#
# Has creado 839 unidades de comida
#
# Has creado 840 unidades de comida
#
# Has creado 841 unidades de comida
#
# Has creado 842 unidades de comida
#
# Has creado 843 unidades de comida
#
# Has creado 844 unidades de comida
#
# Has creado 845 unidades de comida
#
# Has creado 846 unidades de comida
#
# Has creado 847 unidades de comida
#
# Has creado 848 unidades de comida
#
# Has creado 849 unidades de comida
#
# Has creado 850 unidades de comida
#
# Has creado 851 unidades de comida
#
# Has creado 852 unidades de comida
#
# Has creado 853 unidades de comida
#
# Has creado 854 unidades de comida
#
# Has creado 855 unidades de comida
#
# Has creado 856 unidades de comida
#
# Has creado 857 unidades de comida
#
# Has creado 858 unidades de comida
#
# Has creado 859 unidades de comida
#
# Has creado 860 unidades de comida
#
# Has creado 861 unidades de comida
#
# Has creado 862 unidades de comida
#
# Has creado 863 unidades de comida
#
# Has creado 864 unidades de comida
#
# Has creado 865 unidades de comida
#
# Has creado 866 unidades de comida
#
# Has creado 867 unidades de comida
#
# Has creado 868 unidades de comida
#
# Has creado 869 unidades de comida
#
# Has creado 870 unidades de comida
#
# Has creado 871 unidades de comida
#
# Has creado 872 unidades de comida
#
# Has creado 873 unidades de comida
#
# Has creado 874 unidades de comida
#
# Has creado 875 unidades de comida
#
# Has creado 876 unidades de comida
#
# Has creado 877 unidades de comida
#
# Has creado 878 unidades de comida
#
# Has creado 879 unidades de comida
#
# Has creado 880 unidades de comida
#
# Has creado 881 unidades de comida
#
# Has creado 882 unidades de comida
#
# Has creado 883 unidades de comida
#
# Has creado 884 unidades de comida
#
# Has creado 885 unidades de comida
#
# Has creado 886 unidades de comida
#
# Has creado 887 unidades de comida
#
# Has creado 888 unidades de comida
#
# Has creado 889 unidades de comida
#
# Has creado 890 unidades de comida
#
# Has creado 891 unidades de comida
#
# Has creado 892 unidades de comida
#
# Has creado 893 unidades de comida
#
# Has creado 894 unidades de comida
#
# Has creado 895 unidades de comida
#
# Has creado 896 unidades de comida
#
# Has creado 897 unidades de comida
#
# Has creado 898 unidades de comida
#
# Has creado 899 unidades de comida
#
# Has creado 900 unidades de comida
#
# Has creado 901 unidades de comida
#
# Has creado 902 unidades de comida
#
# Has creado 903 unidades de comida
#
# Has creado 904 unidades de comida
#
# Has creado 905 unidades de comida
#
# Has creado 906 unidades de comida
#
# Has creado 907 unidades de comida
#
# Has creado 908 unidades de comida
#
# Has creado 909 unidades de comida
#
# Has creado 910 unidades de comida
#
# Has creado 911 unidades de comida
#
# Has creado 912 unidades de comida
#
# Has creado 913 unidades de comida
#
# Has creado 914 unidades de comida
#
# Has creado 915 unidades de comida
#
# Has creado 916 unidades de comida
#
# Has creado 917 unidades de comida
#
# Has creado 918 unidades de comida
#
# Has creado 919 unidades de comida
#
# Has creado 920 unidades de comida
#
# Has creado 921 unidades de comida
#
# Has creado 922 unidades de comida
#
# Has creado 923 unidades de comida
#
# Has creado 924 unidades de comida
#
# Has creado 925 unidades de comida
#
# Has creado 926 unidades de comida
#
# Has creado 927 unidades de comida
#
# Has creado 928 unidades de comida
#
# Has creado 929 unidades de comida
#
# Has creado 930 unidades de comida
#
# Has creado 931 unidades de comida
#
# Has creado 932 unidades de comida
#
# Has creado 933 unidades de comida
#
# Has creado 934 unidades de comida
#
# Has creado 935 unidades de comida
#
# Has creado 936 unidades de comida
#
# Has creado 937 unidades de comida
#
# Has creado 938 unidades de comida
#
# Has creado 939 unidades de comida
#
# Has creado 940 unidades de comida
#
# Has creado 941 unidades de comida
#
# Has creado 942 unidades de comida
#
# Has creado 943 unidades de comida
#
# Has creado 944 unidades de comida
#
# Has creado 945 unidades de comida
# Has creado 946 unidades de comida
#
# Has creado 947 unidades de comida
#
# Has creado 948 unidades de comida
#
# Has creado 949 unidades de comida
#
# Has creado 950 unidades de comida
#
# Has creado 951 unidades de comida
#
# Has creado 952 unidades de comida
#
# Has creado 953 unidades de comida
#
# Has creado 954 unidades de comida
#
# Has creado 955 unidades de comida
#
# Has creado 956 unidades de comida
#
# Has creado 957 unidades de comida
#
# Has creado 958 unidades de comida
#
# Has creado 959 unidades de comida
#
# Has creado 960 unidades de comida
#
# Has creado 961 unidades de comida
#
# Has creado 962 unidades de comida
#
# Has creado 963 unidades de comida
#
# Has creado 964 unidades de comida
#
# Has creado 965 unidades de comida
#
# Has creado 966 unidades de comida
#
# Has creado 967 unidades de comida
#
# Has creado 968 unidades de comida
#
# Has creado 969 unidades de comida
#
# Has creado 970 unidades de comida
#
# Has creado 971 unidades de comida
#
# Has creado 972 unidades de comida
#
# Has creado 973 unidades de comida
#
# Has creado 974 unidades de comida
#
# Has creado 975 unidades de comida
#
# Has creado 976 unidades de comida
#
# Has creado 977 unidades de comida
#
# Has creado 978 unidades de comida
#
# Has creado 979 unidades de comida
#
# Has creado 980 unidades de comida
#
# Has creado 981 unidades de comida
#
# Has creado 982 unidades de comida
#
# Has creado 983 unidades de comida
#
# Has creado 984 unidades de comida
#
# Has creado 985 unidades de comida
#
# Has creado 986 unidades de comida
#
# Has creado 987 unidades de comida
#
# Has creado 988 unidades de comida
#
# Has creado 989 unidades de comida
#
# Has creado 990 unidades de comida
#
# Has creado 991 unidades de comida
#
# Has creado 992 unidades de comida
#
# Has creado 993 unidades de comida
#
# Has creado 994 unidades de comida
#
# Has creado 995 unidades de comida
#
# Has creado 996 unidades de comida
#
# Has creado 997 unidades de comida
#
# Has creado 998 unidades de comida
#
# Has creado 999 unidades de comida
#
# Has creado 1000 unidades de comida
#
# Has creado 1001 unidades de comida
#
# Has creado 1002 unidades de comida
#
# Has creado 1003 unidades de comida
#
# Has creado 1004 unidades de comida
#
# Has creado 1005 unidades de comida
#
# Has creado 1006 unidades de comida
#
# Has creado 1007 unidades de comida
#
# Has creado 1008 unidades de comida
#
# Has creado 1009 unidades de comida
#
# Has creado 1010 unidades de comida
#
# Has creado 1011 unidades de comida
#
# Has creado 1012 unidades de comida
#
# Has creado 1013 unidades de comida
#
# Has creado 1014 unidades de comida
#
# Has creado 1015 unidades de comida
#
# Has creado 1016 unidades de comida
#
# Has creado 1017 unidades de comida
#
# Has creado 1018 unidades de comida
#
# Has creado 1019 unidades de comida
#
# Has creado 1020 unidades de comida
#
# Has creado 1021 unidades de comida
#
# Has creado 1022 unidades de comida
#
# Has creado 1023 unidades de comida
#
# Has creado 1024 unidades de comida
#
# Has creado 1025 unidades de comida
#
# Has creado 1026 unidades de comida
#
# Has creado 1027 unidades de comida
#
# Has creado 1028 unidades de comida
#
# Has creado 1029 unidades de comida
#
# Has creado 1030 unidades de comida
#
# Has creado 1031 unidades de comida
#
# Has creado 1032 unidades de comida
#
# Has creado 1033 unidades de comida
#
# Has creado 1034 unidades de comida
#
# Has creado 1035 unidades de comida
#
# Has creado 1036 unidades de comida
#
# Has creado 1037 unidades de comida
#
# Has creado 1038 unidades de comida
#
# Has creado 1039 unidades de comida
#
# Has creado 1040 unidades de comida
#
# Has creado 1041 unidades de comida
#
# Has creado 1042 unidades de comida
#
# Has creado 1043 unidades de comida
#
# Has creado 1044 unidades de comida
#
# Has creado 1045 unidades de comida
#
# Has creado 1046 unidades de comida
#
# Has creado 1047 unidades de comida
#
# Has creado 1048 unidades de comida
#
# Has creado 1049 unidades de comida
#
# Has creado 1050 unidades de comida
#
# Has creado 1051 unidades de comida
#
# Has creado 1052 unidades de comida
#
# Has creado 1053 unidades de comida
#
# Has creado 1054 unidades de comida
#
# Has creado 1055 unidades de comida
#
# Has creado 1056 unidades de comida
#
# Has creado 1057 unidades de comida
#
# Has creado 1058 unidades de comida
#
# Has creado 1059 unidades de comida
#
# Has creado 1060 unidades de comida
#
# Has creado 1061 unidades de comida
#
# Has creado 1062 unidades de comida
#
# Has creado 1063 unidades de comida
#
# Has creado 1064 unidades de comida
#
# Has creado 1065 unidades de comida
#
# Has creado 1066 unidades de comida
#
# Has creado 1067 unidades de comida
#
# Has creado 1068 unidades de comida
#
# Has creado 1069 unidades de comida
#
# Has creado 1070 unidades de comida
#
# Has creado 1071 unidades de comida
#
# Has creado 1072 unidades de comida
#
# Has creado 1073 unidades de comida
#
# Has creado 1074 unidades de comida
#
# Has creado 1075 unidades de comida
#
# Has creado 1076 unidades de comida
#
# Has creado 1077 unidades de comida
#
# Has creado 1078 unidades de comida
#
# Has creado 1079 unidades de comida
#
# Has creado 1080 unidades de comida
#
# Has creado 1081 unidades de comida
#
# Has creado 1082 unidades de comida

# %% [markdown]
# Podemos observar que el programa puede crear más de 1000 `QThreads` sin caerse, por lo que se hace evidente que siempre es bueno usar señales, junto con ir eliminando del programa aquellos QThreads y QObjects que ya no son necesarios.
